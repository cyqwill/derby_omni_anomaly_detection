# %%
# !pip install -r requirements.txt

# %%
# !python data_preprocess.py SMD

# %%
# !python main.py --dataset='SMD' --max_epoch=20
# !python main.py --max_epoch=1

# %%
# -*- coding: utf-8 -*-
import logging
import os
import pickle
import sys
import time
import warnings
from argparse import ArgumentParser
from pprint import pformat, pprint

import numpy as np
import tensorflow as tf
import matplotlib
# matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
from tfsnippet.examples.utils import MLResults, print_with_title
from tfsnippet.scaffold import VariableSaver
from tfsnippet.utils import get_variables_as_dict, register_config_arguments, Config

from omni_anomaly.eval_methods import pot_eval, bf_search
from omni_anomaly.model import OmniAnomaly
from omni_anomaly.prediction import Predictor
from omni_anomaly.training import Trainer
from omni_anomaly.utils import get_data_dim, get_data, save_z, preprocess
# Out:
# /root/omni-anomaly-detection/OmniAnomaly/omni_anomaly/vae.py:460: DeprecationWarning: invalid escape sequence \*
#   """
# /root/omni-anomaly-detection/OmniAnomaly/omni_anomaly/vae.py:501: DeprecationWarning: invalid escape sequence \*
#   """
# /opt/conda/lib/python3.6/site-packages/tfsnippet/utils/tfver.py:22: DeprecationWarning: Function 'semver.compare' is deprecated. Deprecated since version 2.10.0.  This function will be removed in semver 3. Use the respective 'semver.VersionInfo.compare' instead.
#   compare_result = semver.compare(version, tf.__version__)
# /opt/conda/lib/python3.6/site-packages/tfsnippet/utils/tfver.py:22: DeprecationWarning: Function 'semver.compare' is deprecated. Deprecated since version 2.10.0.  This function will be removed in semver 3. Use the respective 'semver.VersionInfo.compare' instead.
#   compare_result = semver.compare(version, tf.__version__)

# %%
import pandas as pd

# %% [markdown]
# # Read Data

# %%
prefix = 'DerbysoftServerMachineDataset/'
train_dir = 'train/'
test_dir = 'test/'
file_name = 'derbysoft_server_machine.csv'

# %%
train_df = pd.read_csv(prefix+train_dir+file_name, index_col=0)
train_df.index = pd.to_datetime(train_df.index)

# %%
model_list = list(train_df.columns)
model_list
# Out:
# ['hse_5xx_count_train_data',
#  'hse_fail_rate_train_data',
#  'hse_2xx_count_train_data',
#  'hse_non_2xx_count_train_data',
#  'hse_4xx_count_train_data',
#  'hse_resp_time_train_data']

# %%
fig, axs = plt.subplots(3, 2, figsize=(20, 12), sharex=True)
axx = axs.ravel()
for i in range(0, len(model_list)):
    train_df[model_list[i]].loc["2021-01-01":"2021-05-07"].plot(ax=axx[i])
    axx[i].set_xlabel("date")    
    axx[i].set_ylabel(model_list[i])   
    axx[i].grid(which='minor', axis='x')

# %%
test_df = pd.read_csv(prefix+test_dir+file_name, index_col=0)
test_df.index = pd.to_datetime(test_df.index)

# %%
model_list = list(test_df.columns)
model_list
# Out:
# ['hse_fail_rate_test_data',
#  'hse_5xx_count_test_data',
#  'hse_resp_time_test_data',
#  'hse_non_2xx_count_test_data',
#  'hse_4xx_count_test_data',
#  'hse_2xx_count_test_data']

# %%
fig, axs = plt.subplots(3, 2, figsize=(20, 12), sharex=True)
axx = axs.ravel()
for i in range(0, len(model_list)):
    test_df[model_list[i]].loc["2021-01-01":"2021-05-07"].plot(ax=axx[i])
    axx[i].set_xlabel("date")    
    axx[i].set_ylabel(model_list[i])   
    axx[i].grid(which='minor', axis='x')

# %% [markdown]
# # Robust Anomaly Detection

# %%
class ExpConfig(Config):
    # dataset configuration
    dataset = "machine-1-1"
    x_dim = get_data_dim(dataset)

    # model architecture configuration
    use_connected_z_q = True
    use_connected_z_p = True

    # model parameters
    z_dim = 3
    rnn_cell = 'GRU'  # 'GRU', 'LSTM' or 'Basic'
    rnn_num_hidden = 500
    window_length = 100
    dense_dim = 500
    posterior_flow_type = 'nf'  # 'nf' or None
    nf_layers = 20  # for nf
    max_epoch = 10
    train_start = 0
    max_train_size = None  # `None` means full train set
    batch_size = 50
    l2_reg = 0.0001
    initial_lr = 0.001
    lr_anneal_factor = 0.5
    lr_anneal_epoch_freq = 40
    lr_anneal_step_freq = None
    std_epsilon = 1e-4

    # evaluation parameters
    test_n_z = 1
    test_batch_size = 50
    test_start = 0
    max_test_size = None  # `None` means full test set

    # the range and step-size for score for searching best-f1
    # may vary for different dataset
    bf_search_min = -400.
    bf_search_max = 400.
    bf_search_step_size = 1.

    valid_step_freq = 100
    gradient_clip_norm = 10.

    early_stop = True  # whether to apply early stop method

    # pot parameters
    # recommend values for `level`:
    # SMAP: 0.07
    # MSL: 0.01
    # SMD group 1: 0.0050
    # SMD group 2: 0.0075
    # SMD group 3: 0.0001
    level = 0.005

    # outputs config
    save_z = False  # whether to save sampled z in hidden space
    get_score_on_dim = False  # whether to get score on dim. If `True`, the score will be a 2-dim ndarray
    save_dir = 'model'
    restore_dir = None  # If not None, restore variables from this dir
    result_dir = 'result'  # Where to save the result file
    train_score_filename = 'train_score.pkl'
    test_score_filename = 'test_score.pkl'

# %%
train_df.shape
# Out:
# (69119, 6)

# %%
test_df.shape
# Out:
# (103679, 6)

# %%
train_df.head()
# Out:
#                      hse_5xx_count_train_data  hse_fail_rate_train_data  \
# ds
# 2021-01-31 16:01:00                         1                  0.000444
# 2021-01-31 16:02:00                         1                  0.002231
# 2021-01-31 16:03:00                         1                  0.000525
# 2021-01-31 16:04:00                         1                  0.000525
# 2021-01-31 16:05:00                         0                  0.000502
#
#                      hse_2xx_count_train_data  hse_non_2xx_count_train_data  \
# ds
# 2021-01-31 16:01:00                    119232                            53
# 2021-01-31 16:02:00                    114914                           257
# 2021-01-31 16:03:00                    125558                            66
# 2021-01-31 16:04:00                    125558                            66
# 2021-01-31 16:05:00                    123504                            62
#
#                      hse_4xx_count_train_data  hse_resp_time_train_data
# ds
# 2021-01-31 16:01:00                        39                  0.098871
# 2021-01-31 16:02:00                        47                  0.131711
# 2021-01-31 16:03:00                        38                  0.111384
# 2021-01-31 16:04:00                        38                  0.111384
# 2021-01-31 16:05:00                        44                  0.103066

# %%
# get config obj
config = ExpConfig()

# parse the arguments
# arg_parser = ArgumentParser()
# register_config_arguments(config, arg_parser)
# arg_parser.parse_args(sys.argv[1:])

config.max_epoch = 100
config.train_start = 20000
config.max_train_size = 10000
config.x_dim = train_df.shape[1]
config.restore_dir = 'model'

print_with_title('Configurations', pformat(config.to_dict()), after='\n')

# open the result object and prepare for result directories if specified
results = MLResults(config.result_dir)
results.save_config(config)  # save experiment settings for review
results.make_dirs(config.save_dir, exist_ok=True)
# with warnings.catch_warnings():
#     # suppress DeprecationWarning from NumPy caused by codes in TensorFlow-Probability
#     warnings.filterwarnings("ignore", category=DeprecationWarning, module='numpy')
#     main()
# Out:
# Configurations
# ===========================================
# {'batch_size': 50,
#  'bf_search_max': 400.0,
#  'bf_search_min': -400.0,
#  'bf_search_step_size': 1.0,
#  'dataset': 'machine-1-1',
#  'dense_dim': 500,
#  'early_stop': True,
#  'get_score_on_dim': False,
#  'gradient_clip_norm': 10.0,
#  'initial_lr': 0.001,
#  'l2_reg': 0.0001,
#  'level': 0.005,
#  'lr_anneal_epoch_freq': 40,
#  'lr_anneal_factor': 0.5,
#  'lr_anneal_step_freq': None,
#  'max_epoch': 100,
#  'max_test_size': None,
#  'max_train_size': 10000,
#  'nf_layers': 20,
#  'posterior_flow_type': 'nf',
#  'restore_dir': 'model',
#  'result_dir': 'result',
#  'rnn_cell': 'GRU',
#  'rnn_num_hidden': 500,
#  'save_dir': 'model',
#  'save_z': False,
#  'std_epsilon': 0.0001,
#  'test_batch_size': 50,
#  'test_n_z': 1,
#  'test_score_filename': 'test_score.pkl',
#  'test_start': 0,
#  'train_score_filename': 'train_score.pkl',
#  'train_start': 20000,
#  'use_connected_z_p': True,
#  'use_connected_z_q': True,
#  'valid_step_freq': 100,
#  'window_length': 100,
#  'x_dim': 6,
#  'z_dim': 3}

# %%
logging.basicConfig(
    level='INFO',
    format='%(asctime)s [%(levelname)s] %(name)s: %(message)s'
)

# # prepare the data
# (x_train, _), (x_test, y_test) = \
#     get_data(config.dataset, config.max_train_size, config.max_test_size, train_start=config.train_start,
#              test_start=config.test_start)

if config.max_train_size is None:
    train_end = None
else:
    train_end = config.train_start + config.max_train_size

train_data = train_df.values.reshape((-1, config.x_dim))[config.train_start:train_end, :]
x_train = preprocess(train_data)
# Out:
# Data normalized

# %%
# construct the model under `variable_scope` named 'model'
with tf.variable_scope('model', reuse=tf.AUTO_REUSE) as model_vs:
    model = OmniAnomaly(config=config, name="model")

    # construct the trainer
    trainer = Trainer(model=model,
                      model_vs=model_vs,
                      max_epoch=config.max_epoch,
                      batch_size=config.batch_size,
                      valid_batch_size=config.test_batch_size,
                      initial_lr=config.initial_lr,
                      lr_anneal_epochs=config.lr_anneal_epoch_freq,
                      lr_anneal_factor=config.lr_anneal_factor,
                      grad_clip_norm=config.gradient_clip_norm,
                      valid_step_freq=config.valid_step_freq)

    # construct the predictor
    predictor = Predictor(model, batch_size=config.batch_size, n_z=config.test_n_z,
                          last_point_only=True)

    with tf.Session().as_default():

        if config.restore_dir is not None:
            # Restore variables from `save_dir`.
            saver = VariableSaver(get_variables_as_dict(model_vs), config.restore_dir)
            saver.restore()

        if config.max_epoch > 0:
            # train the model
            train_start = time.time()
            best_valid_metrics = trainer.fit(x_train)
            train_time = (time.time() - train_start) / config.max_epoch
            best_valid_metrics.update({
                'train_time': train_time
            })
        else:
            best_valid_metrics = {}

        # get score of train set for POT algorithm
#         train_score, train_z, train_pred_speed = predictor.get_score(x_train)
#         if config.train_score_filename is not None:
#             with open(os.path.join(config.result_dir, config.train_score_filename), 'wb') as file:
#                 pickle.dump(train_score, file)
#         if config.save_z:
#             save_z(train_z, 'train_z')

        if config.save_dir is not None:
            # save the variables
            var_dict = get_variables_as_dict(model_vs)
            saver = VariableSaver(var_dict, config.save_dir)
            saver.save()
        print('=' * 30 + 'result' + '=' * 30)
        pprint(best_valid_metrics)
# Out:
# INFO:tensorflow:Restoring parameters from /root/omni-anomaly-detection/OmniAnomaly/model/variables.dat
# 2021-07-04 12:53:08,290 [INFO] tensorflow: Restoring parameters from /root/omni-anomaly-detection/OmniAnomaly/model/variables.dat
# Trainable Parameters                                            (2,527,676 in total)
# ------------------------------------------------------------------------------------
# model/q_z_given_x/rnn_q_z/rnn/gru_cell/gates/kernel             (506, 1000)  506,000
# model/q_z_given_x/rnn_q_z/rnn/gru_cell/gates/bias               (1000,)        1,000
# model/q_z_given_x/rnn_q_z/rnn/gru_cell/candidate/kernel         (506, 500)   253,000
# model/q_z_given_x/rnn_q_z/rnn/gru_cell/candidate/bias           (500,)           500
# model/q_z_given_x/rnn_q_z/dense/kernel                          (500, 500)   250,000
# model/q_z_given_x/rnn_q_z/dense/bias                            (500,)           500
# model/q_z_given_x/rnn_q_z/dense_1/kernel                        (500, 500)   250,000
# model/q_z_given_x/rnn_q_z/dense_1/bias                          (500,)           500
# model/vae/variational/z_mean/kernel                             (503, 3)       1,509
# model/vae/variational/z_mean/bias                               (3,)               3
# model/vae/variational/z_std/kernel                              (503, 3)       1,509
# model/vae/variational/z_std/bias                                (3,)               3
# model/posterior_flow/_0/w                                       (1, 3)             3
# model/posterior_flow/_0/b                                       (1,)               1
# model/posterior_flow/_0/u                                       (1, 3)             3
# model/posterior_flow/_1/w                                       (1, 3)             3
# model/posterior_flow/_1/b                                       (1,)               1
# model/posterior_flow/_1/u                                       (1, 3)             3
# model/posterior_flow/_2/w                                       (1, 3)             3
# model/posterior_flow/_2/b                                       (1,)               1
# model/posterior_flow/_2/u                                       (1, 3)             3
# model/posterior_flow/_3/w                                       (1, 3)             3
# model/posterior_flow/_3/b                                       (1,)               1
# model/posterior_flow/_3/u                                       (1, 3)             3
# model/posterior_flow/_4/w                                       (1, 3)             3
# model/posterior_flow/_4/b                                       (1,)               1
# model/posterior_flow/_4/u                                       (1, 3)             3
# model/posterior_flow/_5/w                                       (1, 3)             3
# model/posterior_flow/_5/b                                       (1,)               1
# model/posterior_flow/_5/u                                       (1, 3)             3
# model/posterior_flow/_6/w                                       (1, 3)             3
# model/posterior_flow/_6/b                                       (1,)               1
# model/posterior_flow/_6/u                                       (1, 3)             3
# model/posterior_flow/_7/w                                       (1, 3)             3
# model/posterior_flow/_7/b                                       (1,)               1
# model/posterior_flow/_7/u                                       (1, 3)             3
# model/posterior_flow/_8/w                                       (1, 3)             3
# model/posterior_flow/_8/b                                       (1,)               1
# model/posterior_flow/_8/u                                       (1, 3)             3
# model/posterior_flow/_9/w                                       (1, 3)             3
# model/posterior_flow/_9/b                                       (1,)               1
# model/posterior_flow/_9/u                                       (1, 3)             3
# model/posterior_flow/_10/w                                      (1, 3)             3
# model/posterior_flow/_10/b                                      (1,)               1
# model/posterior_flow/_10/u                                      (1, 3)             3
# model/posterior_flow/_11/w                                      (1, 3)             3
# model/posterior_flow/_11/b                                      (1,)               1
# model/posterior_flow/_11/u                                      (1, 3)             3
# model/posterior_flow/_12/w                                      (1, 3)             3
# model/posterior_flow/_12/b                                      (1,)               1
# model/posterior_flow/_12/u                                      (1, 3)             3
# model/posterior_flow/_13/w                                      (1, 3)             3
# model/posterior_flow/_13/b                                      (1,)               1
# model/posterior_flow/_13/u                                      (1, 3)             3
# model/posterior_flow/_14/w                                      (1, 3)             3
# model/posterior_flow/_14/b                                      (1,)               1
# model/posterior_flow/_14/u                                      (1, 3)             3
# model/posterior_flow/_15/w                                      (1, 3)             3
# model/posterior_flow/_15/b                                      (1,)               1
# model/posterior_flow/_15/u                                      (1, 3)             3
# model/posterior_flow/_16/w                                      (1, 3)             3
# model/posterior_flow/_16/b                                      (1,)               1
# model/posterior_flow/_16/u                                      (1, 3)             3
# model/posterior_flow/_17/w                                      (1, 3)             3
# model/posterior_flow/_17/b                                      (1,)               1
# model/posterior_flow/_17/u                                      (1, 3)             3
# model/posterior_flow/_18/w                                      (1, 3)             3
# model/posterior_flow/_18/b                                      (1,)               1
# model/posterior_flow/_18/u                                      (1, 3)             3
# model/posterior_flow/_19/w                                      (1, 3)             3
# model/posterior_flow/_19/b                                      (1,)               1
# model/posterior_flow/_19/u                                      (1, 3)             3
# model/p_x_given_z/hidden/rnn_p_x/rnn/gru_cell/gates/kernel      (503, 1000)  503,000
# model/p_x_given_z/hidden/rnn_p_x/rnn/gru_cell/gates/bias        (1000,)        1,000
# model/p_x_given_z/hidden/rnn_p_x/rnn/gru_cell/candidate/kernel  (503, 500)   251,500
# model/p_x_given_z/hidden/rnn_p_x/rnn/gru_cell/candidate/bias    (500,)           500
# model/p_x_given_z/hidden/rnn_p_x/dense/kernel                   (500, 500)   250,000
# model/p_x_given_z/hidden/rnn_p_x/dense/bias                     (500,)           500
# model/p_x_given_z/hidden/rnn_p_x/dense_1/kernel                 (500, 500)   250,000
# model/p_x_given_z/hidden/rnn_p_x/dense_1/bias                   (500,)           500
# model/p_x_given_z/x_mean/kernel                                 (500, 6)       3,000
# model/p_x_given_z/x_mean/bias                                   (6,)               6
# model/p_x_given_z/x_std/kernel                                  (500, 6)       3,000
# model/p_x_given_z/x_std/bias                                    (6,)               6
#
# train_values: (7000, 6)
# [Epoch 1/100, Step 100] step time: 0.8671s (±2.461s); train time: 1m 7.068s; valid time: 19.67s; loss: -20.8591 (±0.723654); valid loss: -21.9139 (*)
# train_values: (7000, 6)
# [Epoch 2/100, Step 200, ETA 2h 54m 24.96s] step time: 0.6712s (±1.526s); train time: 32.09s; valid time: 15.34s; loss: -20.912 (±0.771556); valid loss: -21.8904
# train_values: (7000, 6)
# [Epoch 3/100, Step 300, ETA 2h 45m 37.9s] step time: 0.6692s (±1.526s); train time: 12.41s; valid time: 15.33s; loss: -20.9663 (±0.695569); valid loss: -21.7503
# [Epoch 3/100, Step 400, ETA 2h 41m 17.01s] step time: 0.68s (±1.618s); train time: 51.76s; valid time: 16.27s; loss: -21.0194 (±0.70632); valid loss: -22.3451 (*)
# train_values: (7000, 6)
# [Epoch 4/100, Step 500, ETA 2h 38m 11.22s] step time: 0.6791s (±1.621s); train time: 44.39s; valid time: 16.31s; loss: -21.1703 (±0.728989); valid loss: -22.422 (*)
# train_values: (7000, 6)
# [Epoch 5/100, Step 600, ETA 2h 35m 20.42s] step time: 0.6681s (±1.521s); train time: 24.79s; valid time: 15.29s; loss: -21.2178 (±0.675644); valid loss: -21.9342
# train_values: (7000, 6)
# [Epoch 6/100, Step 700, ETA 2h 32m 59.85s] step time: 0.6684s (±1.512s); train time: 5.181s; valid time: 15.2s; loss: -21.3118 (±0.674762); valid loss: -21.8283
# [Epoch 6/100, Step 800, ETA 2h 30m 54.88s] step time: 0.6667s (±1.515s); train time: 51.48s; valid time: 15.22s; loss: -21.3414 (±0.630885); valid loss: -22.2857
# train_values: (7000, 6)
# [Epoch 7/100, Step 900, ETA 2h 29m 2.949s] step time: 0.6667s (±1.512s); train time: 37.12s; valid time: 15.2s; loss: -21.2884 (±0.621329); valid loss: -22.143
# train_values: (7000, 6)
# [Epoch 8/100, Step 1000, ETA 2h 27m 21.98s] step time: 0.6682s (±1.519s); train time: 17.52s; valid time: 15.25s; loss: -21.2823 (±0.683036); valid loss: -22.3302
# [Epoch 8/100, Step 1100, ETA 2h 25m 47.08s] step time: 0.6681s (±1.513s); train time: 51.64s; valid time: 15.2s; loss: -21.3173 (±0.781352); valid loss: -22
# train_values: (7000, 6)
# [Epoch 9/100, Step 1200, ETA 2h 24m 19.31s] step time: 0.6704s (±1.531s); train time: 49.63s; valid time: 15.39s; loss: -20.5128 (±1.69843); valid loss: -20.1722
# train_values: (7000, 6)
# [Epoch 10/100, Step 1300, ETA 2h 22m 55.89s] step time: 0.6716s (±1.539s); train time: 30.03s; valid time: 15.45s; loss: -20.3036 (±0.996592); valid loss: -20.7399
# train_values: (7000, 6)
# [Epoch 11/100, Step 1400, ETA 2h 21m 38.02s] step time: 0.6753s (±1.533s); train time: 10.52s; valid time: 15.4s; loss: -21.1106 (±0.708409); valid loss: -22.284
# [Epoch 11/100, Step 1500, ETA 2h 20m 21.59s] step time: 0.6754s (±1.528s); train time: 52.21s; valid time: 15.35s; loss: -21.2755 (±0.779428); valid loss: -22.3366
# train_values: (7000, 6)
# [Epoch 12/100, Step 1600, ETA 2h 19m 10.72s] step time: 0.6812s (±1.627s); train time: 42.47s; valid time: 16.35s; loss: -21.315 (±0.546628); valid loss: -22.4251 (*)
# train_values: (7000, 6)
# [Epoch 13/100, Step 1700, ETA 2h 18m 1.721s] step time: 0.6834s (±1.634s); train time: 22.89s; valid time: 16.42s; loss: -21.5169 (±0.713749); valid loss: -22.5417 (*)
# train_values: (7000, 6)
# [Epoch 14/100, Step 1800, ETA 2h 16m 45.82s] step time: 0.6729s (±1.523s); train time: 3.178s; valid time: 15.31s; loss: -21.5435 (±0.707019); valid loss: -22.4772
# [Epoch 14/100, Step 1900, ETA 2h 15m 29.78s] step time: 0.6713s (±1.523s); train time: 51.85s; valid time: 15.31s; loss: -21.5153 (±0.802707); valid loss: -22.0637
# train_values: (7000, 6)
# [Epoch 15/100, Step 2000, ETA 2h 14m 15.16s] step time: 0.6722s (±1.524s); train time: 35.3s; valid time: 15.33s; loss: -21.5042 (±0.702259); valid loss: -22.1826
# train_values: (7000, 6)
# [Epoch 16/100, Step 2100, ETA 2h 13m 6.414s] step time: 0.6814s (±1.631s); train time: 15.52s; valid time: 16.39s; loss: -21.5801 (±0.67028); valid loss: -22.5875 (*)
# [Epoch 16/100, Step 2200, ETA 2h 11m 58.05s] step time: 0.6821s (±1.625s); train time: 51.91s; valid time: 16.33s; loss: -21.5958 (±0.70568); valid loss: -22.6244 (*)
# train_values: (7000, 6)
# [Epoch 17/100, Step 2300, ETA 2h 10m 50.28s] step time: 0.6832s (±1.629s); train time: 47.82s; valid time: 16.37s; loss: -21.64 (±0.680305); valid loss: -22.6339 (*)
# train_values: (7000, 6)
# [Epoch 18/100, Step 2400, ETA 2h 9m 41.62s] step time: 0.6814s (±1.625s); train time: 27.97s; valid time: 16.33s; loss: -21.6621 (±0.594947); valid loss: -22.7336 (*)
# train_values: (7000, 6)
# [Epoch 19/100, Step 2500, ETA 2h 8m 33.28s] step time: 0.6821s (±1.628s); train time: 8.322s; valid time: 16.36s; loss: -21.7041 (±0.75158); valid loss: -22.8727 (*)
# [Epoch 19/100, Step 2600, ETA 2h 7m 20.98s] step time: 0.6729s (±1.523s); train time: 52.02s; valid time: 15.3s; loss: -21.6114 (±0.588264); valid loss: -22.7439
# train_values: (7000, 6)
# [Epoch 20/100, Step 2700, ETA 2h 6m 9.143s] step time: 0.6731s (±1.53s); train time: 40.47s; valid time: 15.38s; loss: -21.7195 (±0.752428); valid loss: -22.556
# train_values: (7000, 6)
# [Epoch 21/100, Step 2800, ETA 2h 4m 57.29s] step time: 0.6722s (±1.53s); train time: 20.71s; valid time: 15.37s; loss: -21.8103 (±0.645546); valid loss: -22.804
# train_values: (7000, 6)
# [Epoch 22/100, Step 2900, ETA 2h 3m 45.38s] step time: 0.6712s (±1.53s); train time: 1.044s; valid time: 15.38s; loss: -21.725 (±0.703298); valid loss: -22.594
# [Epoch 22/100, Step 3000, ETA 2h 2m 33.73s] step time: 0.6711s (±1.525s); train time: 51.81s; valid time: 15.33s; loss: -19.6536 (±7.50369); valid loss: -18.1331
# train_values: (7000, 6)
# [Epoch 23/100, Step 3100, ETA 2h 1m 22.5s] step time: 0.6715s (±1.523s); train time: 33.24s; valid time: 15.28s; loss: -18.0941 (±2.36928); valid loss: -20.6573
# train_values: (7000, 6)
# [Epoch 24/100, Step 3200, ETA 2h 11.43s] step time: 0.6712s (±1.52s); train time: 13.55s; valid time: 15.28s; loss: -19.8159 (±1.83965); valid loss: -20.4631
# [Epoch 24/100, Step 3300, ETA 1h 59m 0.3715s] step time: 0.6705s (±1.519s); train time: 51.81s; valid time: 15.27s; loss: -21.4649 (±0.649468); valid loss: -22.6058
# train_values: (7000, 6)
# [Epoch 25/100, Step 3400, ETA 1h 57m 48.74s] step time: 0.6678s (±1.511s); train time: 45.4s; valid time: 15.2s; loss: -21.6655 (±0.65007); valid loss: -22.3813
# train_values: (7000, 6)
# [Epoch 26/100, Step 3500, ETA 1h 56m 37.76s] step time: 0.6691s (±1.521s); train time: 25.88s; valid time: 15.28s; loss: -21.7158 (±0.657532); valid loss: -22.8614
# train_values: (7000, 6)
# [Epoch 27/100, Step 3600, ETA 1h 55m 27.03s] step time: 0.6692s (±1.527s); train time: 6.183s; valid time: 15.34s; loss: -21.7794 (±0.731782); valid loss: -22.8377
# [Epoch 27/100, Step 3700, ETA 1h 54m 17s] step time: 0.6711s (±1.525s); train time: 51.81s; valid time: 15.32s; loss: -21.8434 (±0.692246); valid loss: -22.7049
# train_values: (7000, 6)
# [Epoch 28/100, Step 3800, ETA 1h 53m 6.417s] step time: 0.6684s (±1.515s); train time: 38.23s; valid time: 15.24s; loss: -21.8045 (±0.63639); valid loss: -22.8467
# train_values: (7000, 6)
# [Epoch 29/100, Step 3900, ETA 1h 51m 56.08s] step time: 0.6686s (±1.52s); train time: 18.53s; valid time: 15.27s; loss: -21.8488 (±0.761244); valid loss: -22.5466
# [Epoch 29/100, Step 4000, ETA 1h 50m 48.8s] step time: 0.6804s (±1.62s); train time: 51.78s; valid time: 16.28s; loss: -21.9032 (±0.686538); valid loss: -22.8827 (*)
# train_values: (7000, 6)
# [Epoch 30/100, Step 4100, ETA 1h 49m 39.39s] step time: 0.6715s (±1.519s); train time: 50.88s; valid time: 15.27s; loss: -21.8187 (±0.776175); valid loss: -22.6766
# train_values: (7000, 6)
# [Epoch 31/100, Step 4200, ETA 1h 48m 29.84s] step time: 0.6704s (±1.524s); train time: 30.96s; valid time: 15.32s; loss: -21.9558 (±0.69338); valid loss: -22.8293
# train_values: (7000, 6)
# [Epoch 32/100, Step 4300, ETA 1h 47m 20.45s] step time: 0.6706s (±1.527s); train time: 11.43s; valid time: 15.36s; loss: -21.8529 (±0.693282); valid loss: -22.797
# [Epoch 32/100, Step 4400, ETA 1h 46m 11.29s] step time: 0.6713s (±1.526s); train time: 51.81s; valid time: 15.35s; loss: -21.8549 (±0.712253); valid loss: -22.6885
# train_values: (7000, 6)
# [Epoch 33/100, Step 4500, ETA 1h 45m 2.169s] step time: 0.6709s (±1.525s); train time: 43.56s; valid time: 15.34s; loss: -21.9464 (±0.633165); valid loss: -22.8114
# train_values: (7000, 6)
# [Epoch 34/100, Step 4600, ETA 1h 43m 52.93s] step time: 0.67s (±1.522s); train time: 23.78s; valid time: 15.29s; loss: -21.8753 (±0.646303); valid loss: -22.7834
# train_values: (7000, 6)
# [Epoch 35/100, Step 4700, ETA 1h 42m 46s] step time: 0.6814s (±1.624s); train time: 4.152s; valid time: 16.32s; loss: -21.9336 (±0.717648); valid loss: -23.047 (*)
# [Epoch 35/100, Step 4800, ETA 1h 41m 39.21s] step time: 0.6825s (±1.625s); train time: 51.95s; valid time: 16.33s; loss: -21.9637 (±0.720141); valid loss: -23.2131 (*)
# train_values: (7000, 6)
# [Epoch 36/100, Step 4900, ETA 1h 40m 30.56s] step time: 0.6725s (±1.524s); train time: 36.39s; valid time: 15.32s; loss: -21.8153 (±0.723992); valid loss: -22.8295
# train_values: (7000, 6)
# [Epoch 37/100, Step 5000, ETA 1h 39m 21.85s] step time: 0.6718s (±1.522s); train time: 16.61s; valid time: 15.3s; loss: -21.4085 (±3.05562); valid loss: -21.9427
# [Epoch 37/100, Step 5100, ETA 1h 38m 13.23s] step time: 0.6721s (±1.522s); train time: 51.93s; valid time: 15.31s; loss: -16.0572 (±12.965); valid loss: -20.4312
# train_values: (7000, 6)
# [Epoch 38/100, Step 5200, ETA 1h 37m 4.678s] step time: 0.6721s (±1.522s); train time: 48.87s; valid time: 15.29s; loss: -20.4103 (±1.21501); valid loss: -21.8902
# train_values: (7000, 6)
# [Epoch 39/100, Step 5300, ETA 1h 35m 56.05s] step time: 0.6714s (±1.52s); train time: 29.08s; valid time: 15.27s; loss: -21.5115 (±0.690403); valid loss: -23.0877
# train_values: (7000, 6)
# [Epoch 40/100, Step 5400, ETA 1h 34m 47.2s] step time: 0.6695s (±1.52s); train time: 9.281s; valid time: 15.28s; loss: -21.94 (±0.705256); valid loss: -22.8815
# [Epoch 40/100, Step 5500, ETA 1h 33m 38.2s] step time: 0.6682s (±1.523s); train time: 51.54s; valid time: 15.31s; loss: -22.007 (±0.658875); valid loss: -23.1628
# [Epoch 40/100, Step 5520, ETA 1h 33m 19.8s] Learning rate decreased to 0.0005
# train_values: (7000, 6)
# [Epoch 41/100, Step 5600, ETA 1h 32m 29.27s] step time: 0.668s (±1.519s); train time: 41.28s; valid time: 15.27s; loss: -22.0127 (±0.626876); valid loss: -22.8893
# train_values: (7000, 6)
# [Epoch 42/100, Step 5700, ETA 1h 31m 20.52s] step time: 0.6688s (±1.525s); train time: 21.75s; valid time: 15.32s; loss: -22.0211 (±0.734611); valid loss: -23.0478
# train_values: (7000, 6)
# [Epoch 43/100, Step 5800, ETA 1h 30m 11.67s] step time: 0.6677s (±1.516s); train time: 2.059s; valid time: 15.24s; loss: -21.93 (±0.738765); valid loss: -22.7006
# [Epoch 43/100, Step 5900, ETA 1h 29m 2.87s] step time: 0.6675s (±1.512s); train time: 51.57s; valid time: 15.21s; loss: -22.0757 (±0.699063); valid loss: -22.9992
# train_values: (7000, 6)
# [Epoch 44/100, Step 6000, ETA 1h 27m 54.31s] step time: 0.6688s (±1.52s); train time: 34.12s; valid time: 15.26s; loss: -21.9789 (±0.702673); valid loss: -22.9159
# train_values: (7000, 6)
# [Epoch 45/100, Step 6100, ETA 1h 26m 45.62s] step time: 0.6674s (±1.505s); train time: 14.49s; valid time: 15.13s; loss: -22.0249 (±0.710303); valid loss: -22.9325
# [Epoch 45/100, Step 6200, ETA 1h 25m 37.04s] step time: 0.6678s (±1.518s); train time: 51.55s; valid time: 15.26s; loss: -22.0296 (±0.642736); valid loss: -23.0694
# train_values: (7000, 6)
# [Epoch 46/100, Step 6300, ETA 1h 24m 28.7s] step time: 0.6694s (±1.513s); train time: 46.58s; valid time: 15.21s; loss: -22.0357 (±0.702772); valid loss: -22.897
# train_values: (7000, 6)
# [Epoch 47/100, Step 6400, ETA 1h 23m 20.38s] step time: 0.6691s (±1.516s); train time: 27.01s; valid time: 15.23s; loss: -22.0029 (±0.659999); valid loss: -22.9353
# train_values: (7000, 6)
# [Epoch 48/100, Step 6500, ETA 1h 22m 12.26s] step time: 0.6705s (±1.513s); train time: 7.236s; valid time: 15.21s; loss: -22.0319 (±0.689466); valid loss: -22.8181
# [Epoch 48/100, Step 6600, ETA 1h 21m 4.224s] step time: 0.6711s (±1.519s); train time: 51.86s; valid time: 15.27s; loss: -22.069 (±0.60036); valid loss: -22.9392
# train_values: (7000, 6)
# [Epoch 49/100, Step 6700, ETA 1h 19m 56.05s] step time: 0.6695s (±1.513s); train time: 39.36s; valid time: 15.21s; loss: -22.0717 (±0.706239); valid loss: -22.8648
# train_values: (7000, 6)
# [Epoch 50/100, Step 6800, ETA 1h 18m 48.23s] step time: 0.6725s (±1.517s); train time: 19.78s; valid time: 15.26s; loss: -22.0418 (±0.745055); valid loss: -22.878
# [Epoch 50/100, Step 6900, ETA 1h 17m 40.65s] step time: 0.6748s (±1.533s); train time: 52.12s; valid time: 15.4s; loss: -22.051 (±0.682681); valid loss: -22.7398
# train_values: (7000, 6)
# [Epoch 51/100, Step 7000, ETA 1h 16m 33.31s] step time: 0.6772s (±1.544s); train time: 52.23s; valid time: 15.53s; loss: -22.0689 (±0.651709); valid loss: -22.9369
# train_values: (7000, 6)
# [Epoch 52/100, Step 7100, ETA 1h 15m 25.6s] step time: 0.6734s (±1.53s); train time: 32.15s; valid time: 15.38s; loss: -22.0777 (±0.627464); valid loss: -22.988
# train_values: (7000, 6)
# [Epoch 53/100, Step 7200, ETA 1h 14m 17.75s] step time: 0.6718s (±1.531s); train time: 12.44s; valid time: 15.38s; loss: -22.047 (±0.668903); valid loss: -22.9386
# [Epoch 53/100, Step 7300, ETA 1h 13m 9.978s] step time: 0.6726s (±1.528s); train time: 51.95s; valid time: 15.33s; loss: -22.1403 (±0.705537); valid loss: -22.9799
# train_values: (7000, 6)
# [Epoch 54/100, Step 7400, ETA 1h 12m 2.101s] step time: 0.6711s (±1.525s); train time: 44.6s; valid time: 15.33s; loss: -22.0203 (±0.622044); valid loss: -22.9064
# train_values: (7000, 6)
# [Epoch 55/100, Step 7500, ETA 1h 10m 54.32s] step time: 0.672s (±1.524s); train time: 24.89s; valid time: 15.32s; loss: -22.174 (±0.755297); valid loss: -23.0001
# train_values: (7000, 6)
# [Epoch 56/100, Step 7600, ETA 1h 9m 46.69s] step time: 0.6737s (±1.526s); train time: 5.192s; valid time: 15.33s; loss: -22.0542 (±0.668287); valid loss: -23.1058
# [Epoch 56/100, Step 7700, ETA 1h 8m 38.95s] step time: 0.6723s (±1.521s); train time: 51.98s; valid time: 15.28s; loss: -22.0773 (±0.651067); valid loss: -23.0109
# train_values: (7000, 6)
# [Epoch 57/100, Step 7800, ETA 1h 7m 31.27s] step time: 0.6728s (±1.524s); train time: 37.42s; valid time: 15.32s; loss: -22.1443 (±0.671033); valid loss: -23.1032
# train_values: (7000, 6)
# [Epoch 58/100, Step 7900, ETA 1h 6m 23.51s] step time: 0.6718s (±1.528s); train time: 17.63s; valid time: 15.34s; loss: -22.1056 (±0.648382); valid loss: -23.0172
# [Epoch 58/100, Step 8000, ETA 1h 5m 15.73s] step time: 0.6712s (±1.526s); train time: 51.81s; valid time: 15.34s; loss: -22.1235 (±0.779476); valid loss: -22.9522
# train_values: (7000, 6)
# [Epoch 59/100, Step 8100, ETA 1h 4m 8.68s] step time: 0.6814s (±1.619s); train time: 49.84s; valid time: 16.27s; loss: -22.1534 (±0.761753); valid loss: -23.2415 (*)
# train_values: (7000, 6)
# [Epoch 60/100, Step 8200, ETA 1h 3m 0.9597s] step time: 0.6719s (±1.526s); train time: 30.05s; valid time: 15.34s; loss: -22.1247 (±0.700196); valid loss: -23.1198
# train_values: (7000, 6)
# [Epoch 61/100, Step 8300, ETA 1h 1m 53.3s] step time: 0.6726s (±1.522s); train time: 10.42s; valid time: 15.3s; loss: -22.0959 (±0.730939); valid loss: -23.0997
# [Epoch 61/100, Step 8400, ETA 1h 46.36s] step time: 0.6838s (±1.634s); train time: 51.99s; valid time: 16.41s; loss: -22.1932 (±0.776862); valid loss: -23.3727 (*)
# train_values: (7000, 6)
# [Epoch 62/100, Step 8500, ETA 59m 38.71s] step time: 0.673s (±1.532s); train time: 42.54s; valid time: 15.41s; loss: -22.1303 (±0.679755); valid loss: -23.1678
# train_values: (7000, 6)
# [Epoch 63/100, Step 8600, ETA 58m 30.93s] step time: 0.6707s (±1.526s); train time: 22.72s; valid time: 15.32s; loss: -22.1641 (±0.71822); valid loss: -23.1733
# train_values: (7000, 6)
# [Epoch 64/100, Step 8700, ETA 57m 23.13s] step time: 0.6699s (±1.52s); train time: 3.155s; valid time: 15.28s; loss: -22.1856 (±0.665774); valid loss: -23.2023
# [Epoch 64/100, Step 8800, ETA 56m 15.1s] step time: 0.6658s (±1.511s); train time: 51.42s; valid time: 15.19s; loss: -22.1914 (±0.64647); valid loss: -23.0016
# train_values: (7000, 6)
# [Epoch 65/100, Step 8900, ETA 55m 7.11s] step time: 0.6658s (±1.521s); train time: 34.86s; valid time: 15.27s; loss: -22.2669 (±0.618764); valid loss: -23.1828
# train_values: (7000, 6)
# [Epoch 66/100, Step 9000, ETA 53m 59.31s] step time: 0.6688s (±1.517s); train time: 15.52s; valid time: 15.25s; loss: -22.1525 (±0.722323); valid loss: -23.162
# [Epoch 66/100, Step 9100, ETA 52m 51.51s] step time: 0.6685s (±1.521s); train time: 51.59s; valid time: 15.29s; loss: -22.2286 (±0.620697); valid loss: -23.289
# train_values: (7000, 6)
# [Epoch 67/100, Step 9200, ETA 51m 43.77s] step time: 0.6692s (±1.524s); train time: 47.51s; valid time: 15.33s; loss: -22.2612 (±0.790233); valid loss: -23.3576
# train_values: (7000, 6)
# [Epoch 68/100, Step 9300, ETA 50m 35.97s] step time: 0.6677s (±1.515s); train time: 27.81s; valid time: 15.22s; loss: -22.1379 (±0.754686); valid loss: -23.033
# train_values: (7000, 6)
# [Epoch 69/100, Step 9400, ETA 49m 28.03s] step time: 0.6641s (±1.511s); train time: 8.202s; valid time: 15.19s; loss: -22.2747 (±0.636843); valid loss: -23.1148
# [Epoch 69/100, Step 9500, ETA 48m 20.22s] step time: 0.6664s (±1.513s); train time: 51.46s; valid time: 15.21s; loss: -22.2529 (±0.781067); valid loss: -23.2059
# train_values: (7000, 6)
# [Epoch 70/100, Step 9600, ETA 47m 12.46s] step time: 0.6669s (±1.514s); train time: 40.18s; valid time: 15.22s; loss: -22.2195 (±0.56395); valid loss: -22.9356
# train_values: (7000, 6)
# [Epoch 71/100, Step 9700, ETA 46m 4.801s] step time: 0.6689s (±1.515s); train time: 20.63s; valid time: 15.24s; loss: -22.2828 (±0.688058); valid loss: -23.2629
# train_values: (7000, 6)
# [Epoch 72/100, Step 9800, ETA 44m 57.04s] step time: 0.6659s (±1.514s); train time: 1.038s; valid time: 15.22s; loss: -22.2626 (±0.673532); valid loss: -23.2829
# [Epoch 72/100, Step 9900, ETA 43m 49.72s] step time: 0.6767s (±1.607s); train time: 51.54s; valid time: 16.16s; loss: -22.2401 (±0.693068); valid loss: -23.4124 (*)
# train_values: (7000, 6)
# [Epoch 73/100, Step 10000, ETA 42m 42.06s] step time: 0.6678s (±1.513s); train time: 32.92s; valid time: 15.21s; loss: -22.2024 (±0.671049); valid loss: -23.1901
# train_values: (7000, 6)
# [Epoch 74/100, Step 10100, ETA 41m 34.49s] step time: 0.6699s (±1.519s); train time: 13.4s; valid time: 15.27s; loss: -22.1764 (±0.612112); valid loss: -23.1227
# [Epoch 74/100, Step 10200, ETA 40m 26.91s] step time: 0.6693s (±1.52s); train time: 51.67s; valid time: 15.29s; loss: -22.2748 (±0.730225); valid loss: -23.181
# train_values: (7000, 6)
# [Epoch 75/100, Step 10300, ETA 39m 19.3s] step time: 0.6682s (±1.513s); train time: 45.43s; valid time: 15.2s; loss: -22.3506 (±0.707889); valid loss: -23.3407
# train_values: (7000, 6)
# [Epoch 76/100, Step 10400, ETA 38m 11.69s] step time: 0.6677s (±1.526s); train time: 25.79s; valid time: 15.32s; loss: -22.2839 (±0.681076); valid loss: -23.2001
# train_values: (7000, 6)
# [Epoch 77/100, Step 10500, ETA 37m 4.444s] step time: 0.6786s (±1.622s); train time: 6.227s; valid time: 16.25s; loss: -22.3878 (±0.612549); valid loss: -23.4518 (*)
# [Epoch 77/100, Step 10600, ETA 35m 56.87s] step time: 0.6683s (±1.517s); train time: 51.6s; valid time: 15.25s; loss: -22.3203 (±0.608497); valid loss: -23.2422
# train_values: (7000, 6)
# [Epoch 78/100, Step 10700, ETA 34m 49.25s] step time: 0.6661s (±1.522s); train time: 38.05s; valid time: 15.29s; loss: -22.4498 (±0.799608); valid loss: -23.2608
# train_values: (7000, 6)
# [Epoch 79/100, Step 10800, ETA 33m 41.72s] step time: 0.6689s (±1.518s); train time: 18.55s; valid time: 15.26s; loss: -22.297 (±0.650255); valid loss: -23.275
# [Epoch 79/100, Step 10900, ETA 32m 34.43s] step time: 0.6772s (±1.622s); train time: 51.45s; valid time: 16.29s; loss: -22.3806 (±0.671771); valid loss: -23.453 (*)
# train_values: (7000, 6)
# [Epoch 80/100, Step 11000, ETA 31m 26.87s] step time: 0.6672s (±1.52s); train time: 50.44s; valid time: 15.28s; loss: -22.4023 (±0.732225); valid loss: -23.359
# [Epoch 80/100, Step 11040, ETA 30m 58.34s] Learning rate decreased to 0.00025
# train_values: (7000, 6)
# [Epoch 81/100, Step 11100, ETA 30m 19.58s] step time: 0.6775s (±1.61s); train time: 30.92s; valid time: 16.2s; loss: -22.3843 (±0.605105); valid loss: -23.454 (*)
# train_values: (7000, 6)
# [Epoch 82/100, Step 11200, ETA 29m 12.31s] step time: 0.6788s (±1.621s); train time: 11.37s; valid time: 16.27s; loss: -22.4129 (±0.667414); valid loss: -23.4897 (*)
# [Epoch 82/100, Step 11300, ETA 28m 4.818s] step time: 0.6694s (±1.52s); train time: 51.68s; valid time: 15.28s; loss: -22.4107 (±0.802237); valid loss: -23.396
# train_values: (7000, 6)
# [Epoch 83/100, Step 11400, ETA 26m 57.37s] step time: 0.6708s (±1.521s); train time: 43.53s; valid time: 15.28s; loss: -22.4308 (±0.681645); valid loss: -23.3672
# train_values: (7000, 6)
# [Epoch 84/100, Step 11500, ETA 25m 49.87s] step time: 0.6684s (±1.519s); train time: 23.78s; valid time: 15.27s; loss: -22.4657 (±0.678824); valid loss: -23.2858
# train_values: (7000, 6)
# [Epoch 85/100, Step 11600, ETA 24m 42.6s] step time: 0.6793s (±1.619s); train time: 4.145s; valid time: 16.28s; loss: -22.417 (±0.605523); valid loss: -23.5067 (*)
# [Epoch 85/100, Step 11700, ETA 23m 35.12s] step time: 0.6688s (±1.515s); train time: 51.7s; valid time: 15.21s; loss: -22.431 (±0.70358); valid loss: -23.3147
# train_values: (7000, 6)
# [Epoch 86/100, Step 11800, ETA 22m 27.84s] step time: 0.6798s (±1.619s); train time: 36.26s; valid time: 16.27s; loss: -22.5881 (±0.674861); valid loss: -23.5139 (*)
# train_values: (7000, 6)
# [Epoch 87/100, Step 11900, ETA 21m 20.39s] step time: 0.6699s (±1.519s); train time: 16.57s; valid time: 15.27s; loss: -22.3874 (±0.702593); valid loss: -23.395
# [Epoch 87/100, Step 12000, ETA 20m 13.07s] step time: 0.6783s (±1.622s); train time: 51.56s; valid time: 16.3s; loss: -22.4675 (±0.64921); valid loss: -23.5904 (*)
# train_values: (7000, 6)
# [Epoch 88/100, Step 12100, ETA 19m 5.595s] step time: 0.6676s (±1.516s); train time: 48.46s; valid time: 15.24s; loss: -22.424 (±0.71025); valid loss: -23.4196
# train_values: (7000, 6)
# [Epoch 89/100, Step 12200, ETA 17m 58.12s] step time: 0.6667s (±1.518s); train time: 28.77s; valid time: 15.25s; loss: -22.4514 (±0.703588); valid loss: -23.3962
# train_values: (7000, 6)
# [Epoch 90/100, Step 12300, ETA 16m 50.64s] step time: 0.6655s (±1.514s); train time: 9.266s; valid time: 15.22s; loss: -22.521 (±0.682404); valid loss: -23.438
# [Epoch 90/100, Step 12400, ETA 15m 43.18s] step time: 0.6662s (±1.511s); train time: 51.47s; valid time: 15.18s; loss: -22.4499 (±0.670392); valid loss: -23.2916
# train_values: (7000, 6)
# [Epoch 91/100, Step 12500, ETA 14m 35.77s] step time: 0.6696s (±1.513s); train time: 41.55s; valid time: 15.21s; loss: -22.5384 (±0.677417); valid loss: -23.4759
# train_values: (7000, 6)
# [Epoch 92/100, Step 12600, ETA 13m 28.41s] step time: 0.6734s (±1.531s); train time: 21.91s; valid time: 15.38s; loss: -22.473 (±0.748105); valid loss: -23.463
# train_values: (7000, 6)
# [Epoch 93/100, Step 12700, ETA 12m 21.04s] step time: 0.6733s (±1.527s); train time: 2.099s; valid time: 15.34s; loss: -22.5122 (±0.708301); valid loss: -23.4092
# [Epoch 93/100, Step 12800, ETA 11m 13.67s] step time: 0.6731s (±1.524s); train time: 52.02s; valid time: 15.32s; loss: -22.4477 (±0.695023); valid loss: -23.3102
# train_values: (7000, 6)
# [Epoch 94/100, Step 12900, ETA 10m 6.285s] step time: 0.671s (±1.523s); train time: 34.22s; valid time: 15.31s; loss: -22.5482 (±0.617422); valid loss: -23.3957
# train_values: (7000, 6)
# [Epoch 95/100, Step 13000, ETA 8m 58.91s] step time: 0.6722s (±1.522s); train time: 14.6s; valid time: 15.31s; loss: -22.507 (±0.694969); valid loss: -23.3552
# [Epoch 95/100, Step 13100, ETA 7m 51.53s] step time: 0.6697s (±1.524s); train time: 51.68s; valid time: 15.32s; loss: -22.5685 (±0.73887); valid loss: -23.4236
# train_values: (7000, 6)
# [Epoch 96/100, Step 13200, ETA 6m 44.16s] step time: 0.6708s (±1.528s); train time: 46.56s; valid time: 15.36s; loss: -22.5401 (±0.665789); valid loss: -23.4822
# train_values: (7000, 6)
# [Epoch 97/100, Step 13300, ETA 5m 36.82s] step time: 0.6792s (±1.616s); train time: 26.93s; valid time: 16.24s; loss: -22.5389 (±0.735705); valid loss: -23.5937 (*)
# train_values: (7000, 6)
# [Epoch 98/100, Step 13400, ETA 4m 29.44s] step time: 0.6694s (±1.518s); train time: 7.226s; valid time: 15.26s; loss: -22.4825 (±0.657735); valid loss: -23.34
# [Epoch 98/100, Step 13500, ETA 3m 22.1s] step time: 0.6798s (±1.62s); train time: 51.72s; valid time: 16.28s; loss: -22.5128 (±0.592465); valid loss: -23.6595 (*)
# train_values: (7000, 6)
# [Epoch 99/100, Step 13600, ETA 2m 14.73s] step time: 0.6713s (±1.526s); train time: 39.41s; valid time: 15.33s; loss: -22.5351 (±0.724237); valid loss: -23.4067
# train_values: (7000, 6)
# [Epoch 100/100, Step 13700, ETA 1m 7.363s] step time: 0.6717s (±1.524s); train time: 19.8s; valid time: 15.31s; loss: -22.5854 (±0.676931); valid loss: -23.6362
# [Epoch 100/100, Step 13800, ETA 0s] step time: 0.67s (±1.526s); train time: 51.69s; valid time: 15.34s; loss: -22.5493 (±0.69491); valid loss: -23.4394
# INFO:tensorflow:Restoring parameters from /tmp/tmpwthg0hu3/variables.dat-13500
# 2021-07-04 15:28:05,865 [INFO] tensorflow: Restoring parameters from /tmp/tmpwthg0hu3/variables.dat-13500
# ==============================result==============================
# {'best_valid_loss': -23.659495649235854,
#  'train_time': 92.97050734758378,
#  'valid_time': 0.2592104854351822}

# %% [markdown]
# # Predict Train Data

# %%
train_df.iloc[20000:30000].head()
# Out:
#                      hse_5xx_count_train_data  hse_fail_rate_train_data  \
# ds
# 2021-02-14 13:21:00                         0                  0.000505
# 2021-02-14 13:22:00                         0                  0.000511
# 2021-02-14 13:23:00                         1                  0.000532
# 2021-02-14 13:24:00                         1                  0.000571
# 2021-02-14 13:25:00                         1                  0.000562
#
#                      hse_2xx_count_train_data  hse_non_2xx_count_train_data  \
# ds
# 2021-02-14 13:21:00                    116672                            59
# 2021-02-14 13:22:00                    117405                            60
# 2021-02-14 13:23:00                    114642                            61
# 2021-02-14 13:24:00                    115420                            66
# 2021-02-14 13:25:00                    112024                            63
#
#                      hse_4xx_count_train_data  hse_resp_time_train_data
# ds
# 2021-02-14 13:21:00                        44                  0.086289
# 2021-02-14 13:22:00                        45                  0.086457
# 2021-02-14 13:23:00                        40                  0.086993
# 2021-02-14 13:24:00                        46                  0.086979
# 2021-02-14 13:25:00                        39                  0.089012

# %%
# train_data = train_df[''].values.reshape((-1, config.x_dim))
# x_train = preprocess(train_data)

# %%
# tf.keras.backend.clear_session()

with tf.variable_scope('model', reuse=tf.AUTO_REUSE) as model_vs:
    model = OmniAnomaly(config=config, name="model")
    # construct the predictor
    predictor = Predictor(model, batch_size=config.batch_size, n_z=config.test_n_z,
                          last_point_only=True)
    with tf.Session().as_default():
        
        if config.restore_dir is not None:
            # Restore variables from `save_dir`.
            saver = VariableSaver(get_variables_as_dict(model_vs), config.restore_dir)
            saver.restore()

            train_score, _, _ = predictor.get_score(x_train)
# Out:
# INFO:tensorflow:Restoring parameters from /root/omni-anomaly-detection/OmniAnomaly/model/variables.dat
# 2021-07-04 15:44:12,326 [INFO] tensorflow: Restoring parameters from /root/omni-anomaly-detection/OmniAnomaly/model/variables.dat
# ------------------------------ testing ------------------------------

# %%
len(x_train)
# Out:
# 10000

# %%
len(train_score)
# Out:
# 9901

# %%
train_score_df = pd.DataFrame()
train_score_df['anomaly_score'] = -train_score
train_score_df.index = train_df['2021-02-14 13:21:00':'2021-02-21 12:00:00'].iloc[config.window_length-1:,0].index

# %%
# train_score_df

# %%
model_list = list(train_df.columns)

# %%
fig, axs = plt.subplots(3, 2, figsize=(20, 12), sharex=True)
axx = axs.ravel()
for i in range(0, len(model_list)):
    model_name = model_list[i]
    print('model_name: ', model_name)
    
    axx_2 = axx[i].twinx()           # 做镜像处理
    anomaly_y = train_score_df
    anomaly_y.plot(ax=axx_2, color='black', legend = False)
    origin_y = train_df[model_name].loc[train_score_df.index]
    origin_y.plot(legend = True, ax=axx[i])

    
#     train_df[model_list[i]].loc["2021-04-01":"2021-05-07"].plot(ax=axx[i])
    axx[i].set_xlabel("date")    
    axx[i].set_ylabel(model_list[i])   
    axx[i].grid(which='minor', axis='x')
# Out:
# model_name:  hse_5xx_count_train_data
# model_name:  hse_fail_rate_train_data
# model_name:  hse_2xx_count_train_data
# model_name:  hse_non_2xx_count_train_data
# model_name:  hse_4xx_count_train_data
# model_name:  hse_resp_time_train_data

# %% [markdown]
# # Calculate Threshold

# %%
threshold = np.mean(train_score_df['anomaly_score'])+2*np.std(train_score_df['anomaly_score'])
threshold
# Out:
# 29.645456314086914

# %%
# threshold = 20

# %%
# train_df.head()

# %% [markdown]
# # Plot Anomalies

# %%
# test_mae_loss = test_mae_loss.reshape((-1))
train_mae_loss = np.copy(train_score_df['anomaly_score'])
plt.hist(train_mae_loss, bins=50)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()

# Detect all the samples which are anomalies.
anomalies = (train_mae_loss > threshold).tolist()
print("Number of anomaly samples: ", np.sum(anomalies))
print("Indices of anomaly samples: ", np.where(anomalies))
# Out:
# Number of anomaly samples:  137
# Indices of anomaly samples:  (array([ 342,  358,  494,  495,  544,  575,  624,  639,  718,  765,  813,
#         869,  870,  871,  872,  873,  874,  875,  876,  877,  880,  881,
#         882,  883,  884,  885,  886,  887,  899,  900,  901,  902,  903,
#         904,  905,  906,  907, 2320, 2337, 2429, 2457, 2458, 2466, 2485,
#        2609, 2628, 2647, 2667, 2668, 2688, 2709, 2710, 2730, 2731, 2764,
#        2809, 2830, 2849, 2850, 2868, 2888, 2889, 2908, 2928, 2929, 2968,
#        2969, 2989, 2992, 3048, 3089, 3109, 3194, 3195, 3216, 3242, 3447,
#        4245, 4383, 4451, 4552, 4579, 4667, 4688, 4715, 4789, 4815, 4853,
#        4862, 4914, 4964, 5227, 5228, 5230, 5254, 5299, 5300, 5301, 5306,
#        5307, 6451, 6476, 6501, 6689, 6723, 6796, 6813, 6851, 6897, 6967,
#        6968, 6995, 7024, 7050, 7079, 7107, 7110, 7157, 7177, 7200, 7202,
#        7275, 7389, 7418, 7423, 7434, 8708, 8827, 8848, 8893, 8939, 8941,
#        9015, 9016, 9034, 9036, 9200]),)

# %%
TIME_STEPS = 30

# %%
# data i is an anomaly if samples [(i - timesteps + 1) to (i)] are anomalies
anomalous_data_indices = []
# TIME_STEPS = 288
for data_idx in range(TIME_STEPS - 1, len(train_score_df) - TIME_STEPS + 1):
    time_series = range(data_idx - TIME_STEPS + 1, data_idx)
    # print(np.sum([anomalies[j] for j in time_series]))
    # if all([anomalies[j] for j in time_series]):
    # if np.sum([anomalies[j] for j in time_series])>30:
    if np.sum([anomalies[j] for j in time_series])/TIME_STEPS>0.5:

        anomalous_data_indices.append(data_idx)

# %%
model_list = list(train_df.columns)

# %%
fig, axs = plt.subplots(3, 2, figsize=(20, 12), sharex=True)
axx = axs.ravel()
for i in range(0, len(model_list)):
    model_name = model_list[i]
    print('model_name: ', model_name)

#     anomalous_data_indices = anomalous_data_indices_dict[model_id]
    
    train_df_index_set = set(range(len(train_df.loc[train_score_df.index])))
    anomalous_data_indices_set = set(anomalous_data_indices)
    nan_set = train_df_index_set - anomalous_data_indices_set
    
    df_subset = train_df.loc[train_score_df.index].copy()
    df_subset.iloc[list(nan_set), : ] = np.nan
    
#     df_subset = test_df.iloc[anomalous_data_indices, :]

    # timeseries[i].loc["2020-08-30":"2020-11-5"].plot(ax=axx[i])
    # model_id = 'node_memory_MemAvailable_rate'
    train_df[model_name].loc[train_score_df.index].plot(ax=axx[i])
    if len(anomalous_data_indices)>0:
        df_temp = df_subset[[model_name]].loc[train_score_df.index]
        df_temp.plot(ax=axx[i], color='r',label='anomalies', marker='*')

    axx[i].set_xlabel("date")    
    axx[i].set_ylabel(model_list[i])   
    axx[i].grid(which='minor', axis='x')
# Out:
# model_name:  hse_5xx_count_train_data
# model_name:  hse_fail_rate_train_data
# model_name:  hse_2xx_count_train_data
# model_name:  hse_non_2xx_count_train_data
# model_name:  hse_4xx_count_train_data
# model_name:  hse_resp_time_train_data

# %% [markdown]
# # Predict Test Data

# %%
test_df_cols = list(train_df.columns)
test_df_cols = [x.replace("train","test") for x in test_df_cols]
test_df_cols
# Out:
# ['hse_5xx_count_test_data',
#  'hse_fail_rate_test_data',
#  'hse_2xx_count_test_data',
#  'hse_non_2xx_count_test_data',
#  'hse_4xx_count_test_data',
#  'hse_resp_time_test_data']

# %%
test_df = test_df[test_df_cols]

# %%
test_df.head()
# Out:
#                      hse_5xx_count_test_data  hse_fail_rate_test_data  \
# ds
# 2021-03-20 16:01:00                     3121                 0.023620
# 2021-03-20 16:02:00                     6346                -0.370958
# 2021-03-20 16:03:00                     1067                 0.009016
# 2021-03-20 16:04:00                     3082                 0.023608
# 2021-03-20 16:05:00                     6386                 0.046744
#
#                      hse_2xx_count_test_data  hse_non_2xx_count_test_data  \
# ds
# 2021-03-20 16:01:00                   131041                         3170
# 2021-03-20 16:02:00                   126645                       -34268
# 2021-03-20 16:03:00                   122114                         1111
# 2021-03-20 16:04:00                   129411                         3129
# 2021-03-20 16:05:00                   131127                         6430
#
#                      hse_4xx_count_test_data  hse_resp_time_test_data
# ds
# 2021-03-20 16:01:00                       45                 0.128434
# 2021-03-20 16:02:00                       42                 0.132966
# 2021-03-20 16:03:00                       43                 0.126061
# 2021-03-20 16:04:00                       43                 0.129109
# 2021-03-20 16:05:00                       39                 0.136547

# %%
test_data = test_df['2021-04-01 00:00:00':'2021-06-01 00:00:00'].values.reshape((-1, config.x_dim))
x_test = preprocess(test_data)
# Out:
# Data normalized

# %%
# tf.keras.backend.clear_session()

with tf.variable_scope('model', reuse=tf.AUTO_REUSE) as model_vs:
    model = OmniAnomaly(config=config, name="model")
    # construct the predictor
    predictor = Predictor(model, batch_size=config.batch_size, n_z=config.test_n_z,
                          last_point_only=True)
    with tf.Session().as_default():

        if config.restore_dir is not None:
            # Restore variables from `save_dir`.
            saver = VariableSaver(get_variables_as_dict(model_vs), config.restore_dir)
            saver.restore()

            test_score, _, _ = predictor.get_score(x_test)
# Out:
# INFO:tensorflow:Restoring parameters from /root/omni-anomaly-detection/OmniAnomaly/model/variables.dat
# 2021-07-05 03:22:16,475 [INFO] tensorflow: Restoring parameters from /root/omni-anomaly-detection/OmniAnomaly/model/variables.dat
# ------------------------------ testing ------------------------------

# %%
len(test_score)
# Out:
# 87261

# %%
np.shape(x_test)
# Out:
# (87360, 6)

# %%
test_score_df = pd.DataFrame()
test_score_df['anomaly_score'] = -test_score
test_score_df.index = test_df['2021-04-01 00:00:00':'2021-06-01 00:00:00'].iloc[config.window_length-1:,0].index

# %%
model_list = list(test_df.columns)

# %%
fig, axs = plt.subplots(3, 2, figsize=(20, 12), sharex=True)
axx = axs.ravel()
for i in range(0, len(model_list)):
    model_name = model_list[i]
    print('model_name: ', model_name)
    
    axx_2 = axx[i].twinx()           # 做镜像处理
    anomaly_y = test_score_df
    anomaly_y.plot(ax=axx_2, color='black', legend = False)
    origin_y = test_df[model_name].loc[test_score_df.index]
    origin_y.plot(legend = True, ax=axx[i])

    
#     train_df[model_list[i]].loc["2021-04-01":"2021-05-07"].plot(ax=axx[i])
    axx[i].set_xlabel("date")    
    axx[i].set_ylabel(model_list[i])   
    axx[i].grid(which='minor', axis='x')
# Out:
# model_name:  hse_5xx_count_test_data
# model_name:  hse_fail_rate_test_data
# model_name:  hse_2xx_count_test_data
# model_name:  hse_non_2xx_count_test_data
# model_name:  hse_4xx_count_test_data
# model_name:  hse_resp_time_test_data

# %%
# anomaly_y

# %% [markdown]
# # Plot Anomalies

# %%
# threshold = np.mean(train_score_df['anomaly_score'])+2*np.std(train_score_df['anomaly_score'])
threshold = 100

# %%
threshold
# Out:
# 100

# %%
# test_mae_loss = test_mae_loss.reshape((-1))
test_mae_loss = np.copy(test_score_df['anomaly_score'])
plt.hist(test_mae_loss, bins=50)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()

# Detect all the samples which are anomalies.
anomalies = (test_mae_loss > threshold).tolist()
print("Number of anomaly samples: ", np.sum(anomalies))
print("Indices of anomaly samples: ", np.where(anomalies))
# Out:
# Number of anomaly samples:  1237
# Indices of anomaly samples:  (array([  301,   483,   769, ..., 80043, 80819, 80839]),)

# %%
TIME_STEPS = 30

# %%
# len(test_df)

# %%
# data i is an anomaly if samples [(i - timesteps + 1) to (i)] are anomalies
anomalous_data_indices = []
# TIME_STEPS = 288
for data_idx in range(TIME_STEPS - 1, len(test_score_df) - TIME_STEPS + 1):
    time_series = range(data_idx - TIME_STEPS + 1, data_idx)
    # print(np.sum([anomalies[j] for j in time_series]))
    # if all([anomalies[j] for j in time_series]):
    # if np.sum([anomalies[j] for j in time_series])>30:
    if np.sum([anomalies[j] for j in time_series])/TIME_STEPS>0.5:

        anomalous_data_indices.append(data_idx)

# %%
fig, axs = plt.subplots(3, 2, figsize=(20, 12), sharex=True)
axx = axs.ravel()
for i in range(0, len(model_list)):
    model_name = model_list[i]
    print('model_name: ', model_name)

#     anomalous_data_indices = anomalous_data_indices_dict[model_id]
    
    test_df_index_set = set(range(len(test_df.loc[test_score_df.index])))
    anomalous_data_indices_set = set(anomalous_data_indices)
    nan_set = test_df_index_set - anomalous_data_indices_set
    
    df_subset = test_df.loc[test_score_df.index].copy()
    df_subset.iloc[list(nan_set), : ] = np.nan
    
#     df_subset = test_df.iloc[anomalous_data_indices, :]

    # timeseries[i].loc["2020-08-30":"2020-11-5"].plot(ax=axx[i])
    # model_id = 'node_memory_MemAvailable_rate'
    test_df[model_name].loc[test_score_df.index].plot(ax=axx[i])
    if len(anomalous_data_indices)>0:
        df_temp = df_subset[[model_name]].loc[test_score_df.index]
        df_temp.plot(ax=axx[i], color='r',label='anomalies', marker='*')

    axx[i].set_xlabel("date")    
    axx[i].set_ylabel(model_list[i])   
    axx[i].grid(which='minor', axis='x')
# Out:
# model_name:  hse_5xx_count_test_data
# model_name:  hse_fail_rate_test_data
# model_name:  hse_2xx_count_test_data
# model_name:  hse_non_2xx_count_test_data
# model_name:  hse_4xx_count_test_data
# model_name:  hse_resp_time_test_data
